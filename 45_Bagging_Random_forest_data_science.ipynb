# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split

# %%
from sklearn.datasets import make_moons

# %%
x , y = make_moons(n_samples=1000, noise=0.2)

# %%
df = {'Data 1': x[:, 0], 'Data 2': x[:, 1], 'Target': y}

# %%
database = pd.DataFrame(df)

# %%
database.head(5)
# Out:
#      Data 1    Data 2  Target
# 0  2.027517  0.518793       1
# 1 -0.020908  0.998110       0
# 2  0.706550 -0.534993       1
# 3  0.483959  0.624893       0
# 4  1.973604 -0.105421       1

# %%
sns.scatterplot(x="Data 1", y="Data 2", hue="Target", data=database)
plt.show()

# %%
x_a = database.iloc[:, 0:-1]
y_a = database["Target"]

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
from sklearn.ensemble import BaggingClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC

# %%
bc = BaggingClassifier(estimator=SVC(), n_estimators=100)
bc.fit(x_train, y_train)
# Out:
# BaggingClassifier(estimator=SVC(), n_estimators=100)

# %%
bc.score(x_test, y_test)*100 , bc.score(x_train, y_train)*100
# Out:
# (97.5, 96.625)

# %%
rf = RandomForestClassifier(n_estimators=100)
rf.fit(x_train, y_train)
# Out:
# RandomForestClassifier()

# %%
rf.score(x_test, y_test)*100 , rf.score(x_train, y_train)*100
# Out:
# (95.0, 100.0)
