# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split

# %%
database = pd.read_excel("KMeans.xlsx")
database.head(5)
# Out:
#     Feature1   Feature2
# 0   9.304315   3.157752
# 1  -9.058560  11.069042
# 2  -6.910244  -9.123246
# 3 -10.499838 -10.398769
# 4  -8.353039  -4.756104

# %%
sns.pairplot(data=database)
plt.show()

# %%
from sklearn.cluster import KMeans

# %%
wcss = []
for i in range(2,20):
    kmeans = KMeans(n_clusters=i,  init='k-means++')
    kmeans.fit(database)
    print(i, kmeans.inertia_)
    wcss.append(kmeans.inertia_)
# Out:
# 2 5604.569837646868
# 3 2244.330473723627
# 4 1925.620837576584
# 5 1702.4120592372692
# 6 1469.3463815056573
# 7 1257.154572565155
# 8 1146.9987109880867
# 9 1063.4787689118966
# 10 886.3050972487495
# 11 810.1698053199573
# 12 718.2348819245042
# 13 660.3655878443394
# 14 608.6702175787573
# 15 542.2583103145026
# 16 494.0142917106916
# 17 492.15070014119135
# 18 500.763622456628
# 19 444.84890553761477

# %%
kmeans.labels_
# Out:
# array([13,  5, 14,  0, 10,  4, 11, 10, 16,  4,  6,  2,  8,  6,  6,  0,  7,
#        10, 15,  9, 13,  3, 14, 12, 14,  5,  5, 10, 12,  3,  6, 15, 10,  0,
#         7, 11, 14,  7, 14, 12,  6, 17, 10, 15, 10,  3,  3, 14,  6, 11,  9,
#        11,  9,  1, 17,  7, 18,  3, 17,  6,  9,  5,  4, 14,  9, 14,  5,  1,
#         9, 11, 11, 14, 17,  2,  1,  8,  6,  5, 16, 17, 12,  3,  4, 14, 10,
#        14, 14, 11,  3, 10,  3, 17,  5, 12,  2,  0, 17,  8,  8, 12,  9, 10,
#        17, 14, 11,  2,  4,  2, 13,  0,  8,  8, 12, 14,  5,  0,  4, 17,  7,
#        11,  9, 13, 17, 14,  4,  2,  7,  1,  6,  7,  8, 14, 16, 10,  0,  8,
#         3, 13,  7, 15,  5,  5, 10,  6,  8,  5,  6,  9, 10,  6, 17, 14,  2,
#        10,  6,  4,  0, 11,  8, 15,  7,  3,  8, 10, 11,  8,  3, 17, 14,  8,
#         9, 11,  6, 14, 16, 15,  7, 17, 11,  1, 17,  6, 14,  4,  4,  1,  8,
#         8,  3,  7, 11,  6, 10, 10, 12,  4, 16, 16,  2,  6], dtype=int32)

# %%
plt.plot(range(2,20), wcss)
plt.title("Elbow Method")
plt.xlabel("Number of Clusters")
plt.ylabel("WCSS")
plt.grid(axis="x")
plt.show()

# %%
from sklearn.metrics import silhouette_score

# %%
ss=[]
no_c = [j for j in range(2,21)]
for i in range(2,21):
    kmeans1 = KMeans(n_clusters=i)
    kmeans1.fit(database)
    ss.append(silhouette_score(database, kmeans1.labels_))

# %%
plt.plot(no_c, ss)
plt.title("Silhouette Score")
plt.xlabel("Number of Clusters")
plt.ylabel("Silhouette Score")
plt.grid(axis="x")
plt.show()
