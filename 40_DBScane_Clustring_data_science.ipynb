# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.datasets import make_moons

# %%
x, y = make_moons(n_samples=250, noise=0.05, random_state=42)
df = {'Data 1': x[:, 0], 'Data 2': x[:, 1]}

# %%
database = pd.DataFrame(df)
database.head()
# Out:
#      Data 1    Data 2
# 0  0.084154  0.113341
# 1  1.050915  0.154710
# 2 -0.716555  0.675608
# 3  0.060932  0.926542
# 4 -1.005525  0.336425

# %%
sns.scatter(x="Data 1", y="Data 2", data=database)
plt.show()

# %%
from sklearn.cluster import DBSCAN

# %%
db = DBSCAN(eps=0.2, min_samples=5)
database["Cluster"] = db.fit_predict(database)

# %%
sns.scatterplot(x="Data 1", y="Data 2", hue="Cluster", data=database)
plt.show()
